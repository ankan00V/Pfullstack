# %%
for i in range(1,6):
    for j in range(1,5):
        print("i=",i,"j=",j)
# Out:
# i= 1 j= 1
# i= 1 j= 2
# i= 1 j= 3
# i= 1 j= 4
# i= 2 j= 1
# i= 2 j= 2
# i= 2 j= 3
# i= 2 j= 4
# i= 3 j= 1
# i= 3 j= 2
# i= 3 j= 3
# i= 3 j= 4
# i= 4 j= 1
# i= 4 j= 2
# i= 4 j= 3
# i= 4 j= 4
# i= 5 j= 1
# i= 5 j= 2
# i= 5 j= 3
# i= 5 j= 4

# %%
for i in range(1,6):
    for j in range(1,5):
        print("i=",i,"j=",j)
# Out:
# i= 1 j= 1
# i= 1 j= 2
# i= 1 j= 3
# i= 1 j= 4
# i= 2 j= 1
# i= 2 j= 2
# i= 2 j= 3
# i= 2 j= 4
# i= 3 j= 1
# i= 3 j= 2
# i= 3 j= 3
# i= 3 j= 4
# i= 4 j= 1
# i= 4 j= 2
# i= 4 j= 3
# i= 4 j= 4
# i= 5 j= 1
# i= 5 j= 2
# i= 5 j= 3
# i= 5 j= 4

# %%
for i in range(1,6):
    for j in range(1,5):
        print("*")
# Out:
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *

# %%
for i in range(1,6):
    for j in range(1,5):
        print("*",end=" ")
# Out:
# ********************

# %%
for i in range(1,6):
    for j in range(1,5):
        print("*",end=" ")
    print()
# Out:
# * * * *
# * * * *
# * * * *
# * * * *
# * * * *

# %%
for i in range(1,6):
    for j in range(1,i+1):
        print("i=",i,"j=",j)
# Out:
# i= 1 j= 1
# i= 2 j= 1
# i= 2 j= 2
# i= 3 j= 1
# i= 3 j= 2
# i= 3 j= 3
# i= 4 j= 1
# i= 4 j= 2
# i= 4 j= 3
# i= 4 j= 4
# i= 5 j= 1
# i= 5 j= 2
# i= 5 j= 3
# i= 5 j= 4
# i= 5 j= 5

# %%
for i in range(1,6):
    for j in range(1,i+1):
        print("*")
# Out:
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *

# %%
for
